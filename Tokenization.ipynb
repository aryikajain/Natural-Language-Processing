# %% [markdown]
# <a href="https://colab.research.google.com/github/aryikajain/Natural-Language-Processing/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tokenization**

# %% [markdown]
# Tokenization is a fundamental step in Natural Language Processing (NLP). It involves dividing a Textual input into smaller units known as tokens

# %% [markdown]
# **1. Word Tokenization**

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')

text = "Hello everyone. Welcome to GeeksforGeeks."
sentences = word_tokenize(text)
print(sentences)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Hello', 'everyone', '.', 'Welcome', 'to', 'GeeksforGeeks', '.']

# %% [markdown]
# **2. Sentence Tokenization**

# %%
from nltk.tokenize import sent_tokenize
text = "Hello everyone. Welcome to GeeksforGeeks."
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Hello everyone.', 'Welcome to GeeksforGeeks.']

# %% [markdown]
# **3. Character Tokenization**

# %%
text ="i am ryika"
tokens = list(text)
print(tokens)
# Out:
# ['i', ' ', 'a', 'm', ' ', 'r', 'y', 'i', 'k', 'a']

# %% [markdown]
# **4. Whitespace Tokenization**

# %%
text = "I love NLP"
tokens = text.split()
print(tokens)
# Out:
# ['I', 'love', 'NLP']
